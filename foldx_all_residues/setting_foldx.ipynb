# %%
# %pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.84-cp310-cp310-macosx_10_9_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from biopython) (1.26.4)
# Downloading biopython-1.84-cp310-cp310-macosx_10_9_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.7 MB/s eta 0:00:00
# Installing collected packages: biopython
# Successfully installed biopython-1.84
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from Bio.PDB import PDBParser

# Dictionary for mapping three-letter residue codes to one-letter codes
three_to_one_dict = {
    "ALA": "A", "CYS": "C", "ASP": "D", "GLU": "E", "PHE": "F",
    "GLY": "G", "HIS": "H", "ILE": "I", "LYS": "K", "LEU": "L",
    "MET": "M", "ASN": "N", "PRO": "P", "GLN": "Q", "ARG": "R",
    "SER": "S", "THR": "T", "VAL": "V", "TRP": "W", "TYR": "Y",
    "HSE": "H", "MSE": "M", "SEC": "U"  # Include non-standard residues if needed
}

# Input PDB file and config file
pdb_file = "ionized.pdb"
config_file = "config.cfg"
output_dir = "output_foldx"

# Parse the PDB file to extract residues
parser = PDBParser(QUIET=True)
structure = parser.get_structure("protein", pdb_file)

positions = []
for model in structure:
    for chain in model:
        for residue in chain:
            if residue.get_id()[0] == " ":  # Skip heteroatoms and water
                res_name = residue.get_resname()
                res_id = residue.get_id()[1]
                print(f"Processing residue: {res_name} (ID: {res_id}) in chain {chain.id}")

                # Check if the chain ID matches 'U'
                if chain.id == "U":
                    # Convert three-letter code to one-letter code using the dictionary
                    res_name_upper = res_name.upper()
                    if res_name_upper in three_to_one_dict:
                        one_letter_res_name = three_to_one_dict[res_name_upper]
                        positions.append(f"{one_letter_res_name}U{res_id}h")
                    else:
                        # Print a warning for residues not in the dictionary but continue
                        print(f"Warning: {res_name_upper} is not a standard amino acid.")

# Check if any positions were added and print debug info
print(f"Total positions found: {len(positions)}")
if positions:
    positions_str = ",".join(positions)
    print(f"Positions string: {positions_str}")

    # Update the config file
    with open(config_file, "w") as cfg:
        cfg.write(f"""command=PositionScan
output-dir={output_dir}
pdb={pdb_file}
positions={positions_str}
""")
    print(f"Updated {config_file} with {len(positions)} positions.")
else:
    print("No positions were added. Please check for errors.")
# Out:
# Processing residue: LYS (ID: 1) in chain U
# Processing residue: GLU (ID: 2) in chain U
# Processing residue: THR (ID: 3) in chain U
# Processing residue: ALA (ID: 4) in chain U
# Processing residue: ALA (ID: 5) in chain U
# Processing residue: ALA (ID: 6) in chain U
# Processing residue: LYS (ID: 7) in chain U
# Processing residue: PHE (ID: 8) in chain U
# Processing residue: GLU (ID: 9) in chain U
# Processing residue: ARG (ID: 10) in chain U
# Processing residue: GLN (ID: 11) in chain U
# Processing residue: HSE (ID: 12) in chain U
# Processing residue: MET (ID: 13) in chain U
# Processing residue: ASP (ID: 14) in chain U
# Processing residue: SER (ID: 15) in chain U
# Processing residue: SER (ID: 16) in chain U
# Processing residue: THR (ID: 17) in chain U
# Processing residue: SER (ID: 18) in chain U
# Processing residue: ALA (ID: 19) in chain U
# Processing residue: ALA (ID: 20) in chain U
# Processing residue: SER (ID: 21) in chain U
# Processing residue: SER (ID: 22) in chain U
# Processing residue: SER (ID: 23) in chain U
# Processing residue: ASN (ID: 24) in chain U
# Processing residue: TYR (ID: 25) in chain U
# Processing residue: CYS (ID: 26) in chain U
# Processing residue: ASN (ID: 27) in chain U
# Processing residue: GLN (ID: 28) in chain U
# Processing residue: MET (ID: 29) in chain U
# Processing residue: MET (ID: 30) in chain U
# Processing residue: LYS (ID: 31) in chain U
# Processing residue: SER (ID: 32) in chain U
# Processing residue: ARG (ID: 33) in chain U
# Processing residue: ASN (ID: 34) in chain U
# Processing residue: LEU (ID: 35) in chain U
# Processing residue: THR (ID: 36) in chain U
# Processing residue: LYS (ID: 37) in chain U
# Processing residue: ASP (ID: 38) in chain U
# Processing residue: ARG (ID: 39) in chain U
# Processing residue: CYS (ID: 40) in chain U
# Processing residue: LYS (ID: 41) in chain U
# Processing residue: PRO (ID: 42) in chain U
# Processing residue: VAL (ID: 43) in chain U
# Processing residue: ASN (ID: 44) in chain U
# Processing residue: THR (ID: 45) in chain U
# Processing residue: PHE (ID: 46) in chain U
# Processing residue: VAL (ID: 47) in chain U
# Processing residue: HSE (ID: 48) in chain U
# Processing residue: GLU (ID: 49) in chain U
# Processing residue: SER (ID: 50) in chain U
# Processing residue: LEU (ID: 51) in chain U
# Processing residue: ALA (ID: 52) in chain U
# Processing residue: ASP (ID: 53) in chain U
# Processing residue: VAL (ID: 54) in chain U
# Processing residue: GLN (ID: 55) in chain U
# Processing residue: ALA (ID: 56) in chain U
# Processing residue: VAL (ID: 57) in chain U
# Processing residue: CYS (ID: 58) in chain U
# Processing residue: SER (ID: 59) in chain U
# Processing residue: GLN (ID: 60) in chain U
# Processing residue: LYS (ID: 61) in chain U
# Processing residue: ASN (ID: 62) in chain U
# Processing residue: VAL (ID: 63) in chain U
# Processing residue: ALA (ID: 64) in chain U
# Processing residue: CYS (ID: 65) in chain U
# Processing residue: LYS (ID: 66) in chain U
# Processing residue: ASN (ID: 67) in chain U
# Processing residue: GLY (ID: 68) in chain U
# Processing residue: GLN (ID: 69) in chain U
# Processing residue: THR (ID: 70) in chain U
# Processing residue: ASN (ID: 71) in chain U
# Processing residue: CYS (ID: 72) in chain U
# Processing residue: TYR (ID: 73) in chain U
# Processing residue: GLN (ID: 74) in chain U
# Processing residue: SER (ID: 75) in chain U
# Processing residue: TYR (ID: 76) in chain U
# Processing residue: SER (ID: 77) in chain U
# Processing residue: THR (ID: 78) in chain U
# Processing residue: MET (ID: 79) in chain U
# Processing residue: SER (ID: 80) in chain U
# Processing residue: ILE (ID: 81) in chain U
# Processing residue: THR (ID: 82) in chain U
# Processing residue: ASP (ID: 83) in chain U
# Processing residue: CYS (ID: 84) in chain U
# Processing residue: ARG (ID: 85) in chain U
# Processing residue: GLU (ID: 86) in chain U
# Processing residue: THR (ID: 87) in chain U
# Processing residue: GLY (ID: 88) in chain U
# Processing residue: SER (ID: 89) in chain U
# Processing residue: SER (ID: 90) in chain U
# Processing residue: LYS (ID: 91) in chain U
# Processing residue: TYR (ID: 92) in chain U
# Processing residue: PRO (ID: 93) in chain U
# Processing residue: ASN (ID: 94) in chain U
# Processing residue: CYS (ID: 95) in chain U
# Processing residue: ALA (ID: 96) in chain U
# Processing residue: TYR (ID: 97) in chain U
# Processing residue: LYS (ID: 98) in chain U
# Processing residue: THR (ID: 99) in chain U
# Processing residue: THR (ID: 100) in chain U
# Processing residue: GLN (ID: 101) in chain U
# Processing residue: ALA (ID: 102) in chain U
# Processing residue: ASN (ID: 103) in chain U
# Processing residue: LYS (ID: 104) in chain U
# Processing residue: HSE (ID: 105) in chain U
# Processing residue: ILE (ID: 106) in chain U
# Processing residue: ILE (ID: 107) in chain U
# Processing residue: VAL (ID: 108) in chain U
# Processing residue: ALA (ID: 109) in chain U
# Processing residue: CYS (ID: 110) in chain U
# Processing residue: GLU (ID: 111) in chain U
# Processing residue: GLY (ID: 112) in chain U
# Processing residue: ASN (ID: 113) in chain U
# Processing residue: PRO (ID: 114) in chain U
# Processing residue: TYR (ID: 115) in chain U
# Processing residue: VAL (ID: 116) in chain U
# Processing residue: PRO (ID: 117) in chain U
# Processing residue: VAL (ID: 118) in chain U
# Processing residue: HSE (ID: 119) in chain U
# Processing residue: PHE (ID: 120) in chain U
# Processing residue: ASP (ID: 121) in chain U
# Processing residue: ALA (ID: 122) in chain U
# Processing residue: SER (ID: 123) in chain U
# Processing residue: VAL (ID: 124) in chain U
# Processing residue: TIP (ID: 3) in chain W
# Processing residue: TIP (ID: 5) in chain W
# Processing residue: TIP (ID: 7) in chain W
# Processing residue: TIP (ID: 8) in chain W
# Processing residue: TIP (ID: 15) in chain W
# Processing residue: TIP (ID: 26) in chain W
# Processing residue: TIP (ID: 30) in chain W
# Processing residue: TIP (ID: 44) in chain W
# Processing residue: TIP (ID: 46) in chain W
# Processing residue: TIP (ID: 47) in chain W
# Processing residue: TIP (ID: 48) in chain W
# Processing residue: TIP (ID: 52) in chain W
# Processing residue: TIP (ID: 53) in chain W
# Processing residue: TIP (ID: 55) in chain W
# Processing residue: TIP (ID: 56) in chain W
# Processing residue: TIP (ID: 64) in chain W
# Processing residue: TIP (ID: 67) in chain W
# Processing residue: TIP (ID: 71) in chain W
# Processing residue: TIP (ID: 75) in chain W
# Processing residue: TIP (ID: 76) in chain W
# Processing residue: TIP (ID: 86) in chain W
# Processing residue: TIP (ID: 87) in chain W
# Processing residue: TIP (ID: 88) in chain W
# Processing residue: TIP (ID: 94) in chain W
# Processing residue: TIP (ID: 95) in chain W
# Processing residue: TIP (ID: 99) in chain W
# Processing residue: TIP (ID: 111) in chain W
# Processing residue: TIP (ID: 115) in chain W
# Processing residue: TIP (ID: 116) in chain W
# Processing residue: TIP (ID: 123) in chain W
# Processing residue: TIP (ID: 125) in chain W
# Processing residue: TIP (ID: 130) in chain W
# Processing residue: TIP (ID: 131) in chain W
# Processing residue: TIP (ID: 133) in chain W
# Processing residue: TIP (ID: 135) in chain W
# Processing residue: TIP (ID: 137) in chain W
# Processing residue: TIP (ID: 145) in chain W
# Processing residue: TIP (ID: 146) in chain W
# Processing residue: TIP (ID: 149) in chain W
# Processing residue: TIP (ID: 150) in chain W
# Processing residue: TIP (ID: 152) in chain W
# Processing residue: TIP (ID: 153) in chain W
# Processing residue: TIP (ID: 155) in chain W
# Processing residue: TIP (ID: 163) in chain W
# Processing residue: TIP (ID: 167) in chain W
# Processing residue: TIP (ID: 174) in chain W
# Processing residue: TIP (ID: 177) in chain W
# Processing residue: TIP (ID: 178) in chain W
# Processing residue: TIP (ID: 179) in chain W
# Processing residue: TIP (ID: 180) in chain W
# Processing residue: TIP (ID: 190) in chain W
# Processing residue: TIP (ID: 191) in chain W
# Processing residue: TIP (ID: 195) in chain W
# Processing residue: TIP (ID: 196) in chain W
# Processing residue: TIP (ID: 198) in chain W
# Processing residue: TIP (ID: 201) in chain W
# Processing residue: TIP (ID: 222) in chain W
# Processing residue: TIP (ID: 224) in chain W
# Processing residue: TIP (ID: 231) in chain W
# Processing residue: TIP (ID: 237) in chain W
# Processing residue: TIP (ID: 238) in chain W
# Processing residue: TIP (ID: 242) in chain W
# Processing residue: TIP (ID: 255) in chain W
# Processing residue: TIP (ID: 257) in chain W
# Processing residue: TIP (ID: 258) in chain W
# Processing residue: TIP (ID: 259) in chain W
# Processing residue: TIP (ID: 261) in chain W
# Processing residue: TIP (ID: 267) in chain W
# Processing residue: TIP (ID: 281) in chain W
# Processing residue: TIP (ID: 283) in chain W
# Processing residue: TIP (ID: 284) in chain W
# Processing residue: TIP (ID: 285) in chain W
# Processing residue: TIP (ID: 295) in chain W
# Processing residue: TIP (ID: 302) in chain W
# Processing residue: TIP (ID: 303) in chain W
# Processing residue: TIP (ID: 305) in chain W
# Processing residue: TIP (ID: 306) in chain W
# Processing residue: TIP (ID: 307) in chain W
# Processing residue: TIP (ID: 309) in chain W
# Processing residue: TIP (ID: 316) in chain W
# Processing residue: TIP (ID: 317) in chain W
# Processing residue: TIP (ID: 322) in chain W
# Processing residue: TIP (ID: 325) in chain W
# Processing residue: TIP (ID: 329) in chain W
# Processing residue: TIP (ID: 338) in chain W
# Processing residue: TIP (ID: 344) in chain W
# Processing residue: TIP (ID: 346) in chain W
# Processing residue: TIP (ID: 347) in chain W
# Processing residue: TIP (ID: 361) in chain W
# Processing residue: TIP (ID: 365) in chain W
# Processing residue: TIP (ID: 368) in chain W
# Processing residue: TIP (ID: 369) in chain W
# Processing residue: TIP (ID: 371) in chain W
# Processing residue: TIP (ID: 378) in chain W
# Processing residue: TIP (ID: 384) in chain W
# Processing residue: TIP (ID: 388) in chain W
# Processing residue: TIP (ID: 393) in chain W
# Processing residue: TIP (ID: 401) in chain W
# Processing residue: TIP (ID: 403) in chain W
# Processing residue: TIP (ID: 409) in chain W
# Processing residue: TIP (ID: 411) in chain W
# Processing residue: TIP (ID: 424) in chain W
# Processing residue: TIP (ID: 425) in chain W
# Processing residue: TIP (ID: 432) in chain W
# Processing residue: TIP (ID: 433) in chain W
# Processing residue: TIP (ID: 446) in chain W
# Processing residue: TIP (ID: 450) in chain W
# Processing residue: TIP (ID: 452) in chain W
# Processing residue: TIP (ID: 465) in chain W
# Processing residue: TIP (ID: 466) in chain W
# Processing residue: TIP (ID: 468) in chain W
# Processing residue: TIP (ID: 484) in chain W
# Processing residue: TIP (ID: 485) in chain W
# Processing residue: TIP (ID: 486) in chain W
# Processing residue: TIP (ID: 489) in chain W
# Processing residue: TIP (ID: 490) in chain W
# Processing residue: TIP (ID: 491) in chain W
# Processing residue: TIP (ID: 494) in chain W
# Processing residue: TIP (ID: 495) in chain W
# Processing residue: TIP (ID: 498) in chain W
# Processing residue: TIP (ID: 503) in chain W
# Processing residue: TIP (ID: 506) in chain W
# Processing residue: TIP (ID: 507) in chain W
# Processing residue: TIP (ID: 508) in chain W
# Processing residue: TIP (ID: 509) in chain W
# Processing residue: TIP (ID: 511) in chain W
# Processing residue: TIP (ID: 512) in chain W
# Processing residue: TIP (ID: 514) in chain W
# Processing residue: TIP (ID: 516) in chain W
# Processing residue: TIP (ID: 528) in chain W
# Processing residue: TIP (ID: 529) in chain W
# Processing residue: TIP (ID: 538) in chain W
# Processing residue: TIP (ID: 540) in chain W
# Processing residue: TIP (ID: 543) in chain W
# Processing residue: TIP (ID: 549) in chain W
# Processing residue: TIP (ID: 550) in chain W
# Processing residue: TIP (ID: 552) in chain W
# Processing residue: TIP (ID: 553) in chain W
# Processing residue: TIP (ID: 554) in chain W
# Processing residue: TIP (ID: 555) in chain W
# Processing residue: TIP (ID: 558) in chain W
# Processing residue: TIP (ID: 562) in chain W
# Processing residue: TIP (ID: 568) in chain W
# Processing residue: TIP (ID: 570) in chain W
# Processing residue: TIP (ID: 573) in chain W
# Processing residue: TIP (ID: 575) in chain W
# Processing residue: TIP (ID: 576) in chain W
# Processing residue: TIP (ID: 578) in chain W
# Processing residue: TIP (ID: 579) in chain W
# Processing residue: TIP (ID: 580) in chain W
# Processing residue: TIP (ID: 584) in chain W
# Processing residue: TIP (ID: 588) in chain W
# Processing residue: TIP (ID: 591) in chain W
# Processing residue: TIP (ID: 592) in chain W
# Processing residue: TIP (ID: 593) in chain W
# Processing residue: TIP (ID: 594) in chain W
# Processing residue: TIP (ID: 599) in chain W
# Processing residue: TIP (ID: 600) in chain W
# Processing residue: TIP (ID: 602) in chain W
# Processing residue: TIP (ID: 611) in chain W
# Processing residue: TIP (ID: 612) in chain W
# Processing residue: TIP (ID: 613) in chain W
# Processing residue: TIP (ID: 615) in chain W
# Processing residue: TIP (ID: 616) in chain W
# Processing residue: TIP (ID: 619) in chain W
# Processing residue: TIP (ID: 623) in chain W
# Processing residue: TIP (ID: 626) in chain W
# Processing residue: TIP (ID: 634) in chain W
# Processing residue: TIP (ID: 636) in chain W
# Processing residue: TIP (ID: 637) in chain W
# Processing residue: TIP (ID: 638) in chain W
# Processing residue: TIP (ID: 639) in chain W
# Processing residue: TIP (ID: 642) in chain W
# Processing residue: TIP (ID: 653) in chain W
# Processing residue: TIP (ID: 662) in chain W
# Processing residue: TIP (ID: 666) in chain W
# Processing residue: TIP (ID: 674) in chain W
# Processing residue: TIP (ID: 675) in chain W
# Processing residue: TIP (ID: 677) in chain W
# Processing residue: TIP (ID: 679) in chain W
# Processing residue: TIP (ID: 680) in chain W
# Processing residue: TIP (ID: 682) in chain W
# Processing residue: TIP (ID: 684) in chain W
# Processing residue: TIP (ID: 686) in chain W
# Processing residue: TIP (ID: 701) in chain W
# Processing residue: TIP (ID: 702) in chain W
# Processing residue: TIP (ID: 704) in chain W
# Processing residue: TIP (ID: 706) in chain W
# Processing residue: TIP (ID: 707) in chain W
# Processing residue: TIP (ID: 710) in chain W
# Processing residue: TIP (ID: 715) in chain W
# Processing residue: TIP (ID: 717) in chain W
# Processing residue: TIP (ID: 721) in chain W
# Processing residue: TIP (ID: 722) in chain W
# Processing residue: TIP (ID: 725) in chain W
# Processing residue: TIP (ID: 726) in chain W
# Processing residue: TIP (ID: 736) in chain W
# Processing residue: TIP (ID: 737) in chain W
# Processing residue: TIP (ID: 738) in chain W
# Processing residue: TIP (ID: 740) in chain W
# Processing residue: TIP (ID: 744) in chain W
# Processing residue: TIP (ID: 745) in chain W
# Processing residue: TIP (ID: 746) in chain W
# Processing residue: TIP (ID: 748) in chain W
# Processing residue: TIP (ID: 749) in chain W
# Processing residue: TIP (ID: 750) in chain W
# Processing residue: TIP (ID: 757) in chain W
# Processing residue: TIP (ID: 759) in chain W
# Processing residue: TIP (ID: 761) in chain W
# Processing residue: TIP (ID: 763) in chain W
# Processing residue: TIP (ID: 765) in chain W
# Processing residue: TIP (ID: 766) in chain W
# Processing residue: TIP (ID: 767) in chain W
# Processing residue: TIP (ID: 778) in chain W
# Processing residue: TIP (ID: 783) in chain W
# Processing residue: TIP (ID: 785) in chain W
# Processing residue: TIP (ID: 788) in chain W
# Processing residue: TIP (ID: 792) in chain W
# Processing residue: TIP (ID: 796) in chain W
# Processing residue: TIP (ID: 803) in chain W
# Processing residue: TIP (ID: 806) in chain W
# Processing residue: TIP (ID: 809) in chain W
# Processing residue: TIP (ID: 811) in chain W
# Processing residue: TIP (ID: 813) in chain W
# Processing residue: TIP (ID: 817) in chain W
# Processing residue: TIP (ID: 822) in chain W
# Processing residue: TIP (ID: 831) in chain W
# Processing residue: TIP (ID: 849) in chain W
# Processing residue: TIP (ID: 852) in chain W
# Processing residue: TIP (ID: 854) in chain W
# Processing residue: TIP (ID: 865) in chain W
# Processing residue: TIP (ID: 878) in chain W
# Processing residue: TIP (ID: 880) in chain W
# Processing residue: TIP (ID: 883) in chain W
# Processing residue: TIP (ID: 885) in chain W
# Processing residue: TIP (ID: 887) in chain W
# Processing residue: TIP (ID: 889) in chain W
# Processing residue: TIP (ID: 894) in chain W
# Processing residue: TIP (ID: 895) in chain W
# Processing residue: TIP (ID: 897) in chain W
# Processing residue: TIP (ID: 906) in chain W
# Processing residue: TIP (ID: 907) in chain W
# Processing residue: TIP (ID: 908) in chain W
# Processing residue: TIP (ID: 911) in chain W
# Processing residue: TIP (ID: 912) in chain W
# Processing residue: TIP (ID: 915) in chain W
# Processing residue: TIP (ID: 916) in chain W
# Processing residue: TIP (ID: 924) in chain W
# Processing residue: TIP (ID: 927) in chain W
# Processing residue: TIP (ID: 928) in chain W
# Processing residue: TIP (ID: 930) in chain W
# Processing residue: TIP (ID: 933) in chain W
# Processing residue: TIP (ID: 936) in chain W
# Processing residue: TIP (ID: 940) in chain W
# Processing residue: TIP (ID: 941) in chain W
# Processing residue: TIP (ID: 942) in chain W
# Processing residue: TIP (ID: 947) in chain W
# Processing residue: TIP (ID: 948) in chain W
# Processing residue: TIP (ID: 949) in chain W
# Processing residue: TIP (ID: 953) in chain W
# Processing residue: TIP (ID: 954) in chain W
# Processing residue: TIP (ID: 964) in chain W
# Processing residue: TIP (ID: 970) in chain W
# Processing residue: TIP (ID: 972) in chain W
# Processing residue: TIP (ID: 975) in chain W
# Processing residue: TIP (ID: 977) in chain W
# Processing residue: TIP (ID: 978) in chain W
# Processing residue: TIP (ID: 985) in chain W
# Processing residue: TIP (ID: 988) in chain W
# Processing residue: TIP (ID: 989) in chain W
# Processing residue: TIP (ID: 990) in chain W
# Processing residue: TIP (ID: 992) in chain W
# Processing residue: TIP (ID: 996) in chain W
# Processing residue: TIP (ID: 1007) in chain W
# Processing residue: TIP (ID: 1011) in chain W
# Processing residue: TIP (ID: 1013) in chain W
# Processing residue: TIP (ID: 1018) in chain W
# Processing residue: TIP (ID: 1022) in chain W
# Processing residue: TIP (ID: 1023) in chain W
# Processing residue: TIP (ID: 1027) in chain W
# Processing residue: TIP (ID: 1032) in chain W
# Processing residue: TIP (ID: 1033) in chain W
# Processing residue: TIP (ID: 1042) in chain W
# Processing residue: TIP (ID: 1043) in chain W
# Processing residue: TIP (ID: 1055) in chain W
# Processing residue: TIP (ID: 1057) in chain W
# Processing residue: TIP (ID: 1059) in chain W
# Processing residue: TIP (ID: 1061) in chain W
# Processing residue: TIP (ID: 1065) in chain W
# Processing residue: TIP (ID: 1066) in chain W
# Processing residue: TIP (ID: 1072) in chain W
# Processing residue: TIP (ID: 1076) in chain W
# Processing residue: TIP (ID: 1077) in chain W
# Processing residue: TIP (ID: 1078) in chain W
# Processing residue: TIP (ID: 1081) in chain W
# Processing residue: TIP (ID: 1082) in chain W
# Processing residue: TIP (ID: 1083) in chain W
# Processing residue: TIP (ID: 1085) in chain W
# Processing residue: TIP (ID: 1090) in chain W
# Processing residue: TIP (ID: 1096) in chain W
# Processing residue: TIP (ID: 1098) in chain W
# Processing residue: TIP (ID: 1099) in chain W
# Processing residue: TIP (ID: 1101) in chain W
# Processing residue: TIP (ID: 1103) in chain W
# Processing residue: TIP (ID: 1104) in chain W
# Processing residue: TIP (ID: 1105) in chain W
# Processing residue: TIP (ID: 1107) in chain W
# Processing residue: TIP (ID: 1112) in chain W
# Processing residue: TIP (ID: 1115) in chain W
# Processing residue: TIP (ID: 1117) in chain W
# Processing residue: TIP (ID: 1121) in chain W
# Processing residue: TIP (ID: 1122) in chain W
# Processing residue: TIP (ID: 1123) in chain W
# Processing residue: TIP (ID: 1125) in chain W
# Processing residue: TIP (ID: 1128) in chain W
# Processing residue: TIP (ID: 1134) in chain W
# Processing residue: TIP (ID: 1135) in chain W
# Processing residue: TIP (ID: 1137) in chain W
# Processing residue: TIP (ID: 1139) in chain W
# Processing residue: TIP (ID: 1140) in chain W
# Processing residue: TIP (ID: 1143) in chain W
# Processing residue: TIP (ID: 1144) in chain W
# Processing residue: TIP (ID: 1148) in chain W
# Processing residue: TIP (ID: 1150) in chain W
# Processing residue: TIP (ID: 1155) in chain W
# Processing residue: TIP (ID: 1157) in chain W
# Processing residue: TIP (ID: 1158) in chain W
# Processing residue: TIP (ID: 1160) in chain W
# Processing residue: TIP (ID: 1162) in chain W
# Processing residue: TIP (ID: 1163) in chain W
# Processing residue: TIP (ID: 1166) in chain W
# Processing residue: TIP (ID: 1167) in chain W
# Processing residue: TIP (ID: 1178) in chain W
# Processing residue: TIP (ID: 1179) in chain W
# Processing residue: TIP (ID: 1180) in chain W
# Processing residue: TIP (ID: 1181) in chain W
# Processing residue: TIP (ID: 1182) in chain W
# Processing residue: TIP (ID: 1183) in chain W
# Processing residue: TIP (ID: 1184) in chain W
# Processing residue: TIP (ID: 1186) in chain W
# Processing residue: TIP (ID: 1187) in chain W
# Processing residue: TIP (ID: 1188) in chain W
# Processing residue: TIP (ID: 1194) in chain W
# Processing residue: TIP (ID: 1201) in chain W
# Processing residue: TIP (ID: 1204) in chain W
# Processing residue: TIP (ID: 1206) in chain W
# Processing residue: TIP (ID: 1207) in chain W
# Processing residue: TIP (ID: 1211) in chain W
# Processing residue: TIP (ID: 1212) in chain W
# Processing residue: TIP (ID: 1214) in chain W
# Processing residue: TIP (ID: 1215) in chain W
# Processing residue: TIP (ID: 1217) in chain W
# Processing residue: TIP (ID: 1220) in chain W
# Processing residue: TIP (ID: 1222) in chain W
# Processing residue: TIP (ID: 1223) in chain W
# Processing residue: TIP (ID: 1224) in chain W
# Processing residue: TIP (ID: 1229) in chain W
# Processing residue: TIP (ID: 1230) in chain W
# Processing residue: TIP (ID: 1242) in chain W
# Processing residue: TIP (ID: 1248) in chain W
# Processing residue: TIP (ID: 1249) in chain W
# Processing residue: TIP (ID: 1263) in chain W
# Processing residue: TIP (ID: 1265) in chain W
# Processing residue: TIP (ID: 1267) in chain W
# Processing residue: TIP (ID: 1272) in chain W
# Processing residue: TIP (ID: 1274) in chain W
# Processing residue: TIP (ID: 1278) in chain W
# Processing residue: TIP (ID: 1281) in chain W
# Processing residue: TIP (ID: 1284) in chain W
# Processing residue: TIP (ID: 1287) in chain W
# Processing residue: TIP (ID: 1295) in chain W
# Processing residue: TIP (ID: 1298) in chain W
# Processing residue: TIP (ID: 1301) in chain W
# Processing residue: TIP (ID: 1307) in chain W
# Processing residue: TIP (ID: 1309) in chain W
# Processing residue: TIP (ID: 1311) in chain W
# Processing residue: TIP (ID: 1317) in chain W
# Processing residue: TIP (ID: 1324) in chain W
# Processing residue: TIP (ID: 1326) in chain W
# Processing residue: TIP (ID: 1327) in chain W
# Processing residue: TIP (ID: 1328) in chain W
# Processing residue: TIP (ID: 1329) in chain W
# Processing residue: TIP (ID: 1330) in chain W
# Processing residue: TIP (ID: 1332) in chain W
# Processing residue: TIP (ID: 1334) in chain W
# Processing residue: TIP (ID: 1337) in chain W
# Processing residue: TIP (ID: 1344) in chain W
# Processing residue: TIP (ID: 1346) in chain W
# Processing residue: TIP (ID: 1347) in chain W
# Processing residue: TIP (ID: 1352) in chain W
# Processing residue: TIP (ID: 1354) in chain W
# Processing residue: TIP (ID: 1356) in chain W
# Processing residue: TIP (ID: 1357) in chain W
# Processing residue: TIP (ID: 1367) in chain W
# Processing residue: TIP (ID: 1368) in chain W
# Processing residue: TIP (ID: 1370) in chain W
# Processing residue: TIP (ID: 1371) in chain W
# Processing residue: TIP (ID: 1372) in chain W
# Processing residue: TIP (ID: 1379) in chain W
# Processing residue: TIP (ID: 1380) in chain W
# Processing residue: TIP (ID: 1387) in chain W
# Processing residue: TIP (ID: 1394) in chain W
# Processing residue: TIP (ID: 1395) in chain W
# Processing residue: TIP (ID: 1398) in chain W
# Processing residue: TIP (ID: 1401) in chain W
# Processing residue: TIP (ID: 1407) in chain W
# Processing residue: TIP (ID: 1408) in chain W
# Processing residue: TIP (ID: 1411) in chain W
# Processing residue: TIP (ID: 1412) in chain W
# Processing residue: TIP (ID: 1414) in chain W
# Processing residue: TIP (ID: 1418) in chain W
# Processing residue: TIP (ID: 1428) in chain W
# Processing residue: TIP (ID: 1429) in chain W
# Processing residue: TIP (ID: 1431) in chain W
# Processing residue: TIP (ID: 1436) in chain W
# Processing residue: TIP (ID: 1437) in chain W
# Processing residue: TIP (ID: 1439) in chain W
# Processing residue: TIP (ID: 1440) in chain W
# Processing residue: TIP (ID: 1442) in chain W
# Processing residue: TIP (ID: 1443) in chain W
# Processing residue: TIP (ID: 1450) in chain W
# Processing residue: TIP (ID: 1451) in chain W
# Processing residue: TIP (ID: 1453) in chain W
# Processing residue: TIP (ID: 1456) in chain W
# Processing residue: TIP (ID: 1458) in chain W
# Processing residue: TIP (ID: 1459) in chain W
# Processing residue: TIP (ID: 1460) in chain W
# Processing residue: TIP (ID: 1461) in chain W
# Processing residue: TIP (ID: 1463) in chain W
# Processing residue: TIP (ID: 1466) in chain W
# Processing residue: TIP (ID: 1471) in chain W
# Processing residue: TIP (ID: 1476) in chain W
# Processing residue: TIP (ID: 1477) in chain W
# Processing residue: TIP (ID: 1480) in chain W
# Processing residue: TIP (ID: 1483) in chain W
# Processing residue: TIP (ID: 1485) in chain W
# Processing residue: TIP (ID: 1492) in chain W
# Processing residue: TIP (ID: 1497) in chain W
# Processing residue: TIP (ID: 1498) in chain W
# Processing residue: TIP (ID: 1501) in chain W
# Processing residue: TIP (ID: 1502) in chain W
# Processing residue: TIP (ID: 1507) in chain W
# Processing residue: TIP (ID: 1514) in chain W
# Processing residue: TIP (ID: 1515) in chain W
# Processing residue: TIP (ID: 1518) in chain W
# Processing residue: TIP (ID: 1520) in chain W
# Processing residue: TIP (ID: 1522) in chain W
# Processing residue: TIP (ID: 1524) in chain W
# Processing residue: TIP (ID: 1526) in chain W
# Processing residue: TIP (ID: 1527) in chain W
# Processing residue: TIP (ID: 1536) in chain W
# Processing residue: TIP (ID: 1543) in chain W
# Processing residue: TIP (ID: 1544) in chain W
# Processing residue: TIP (ID: 1546) in chain W
# Processing residue: TIP (ID: 1547) in chain W
# Processing residue: TIP (ID: 1552) in chain W
# Processing residue: TIP (ID: 1557) in chain W
# Processing residue: TIP (ID: 1562) in chain W
# Processing residue: TIP (ID: 1563) in chain W
# Processing residue: TIP (ID: 1565) in chain W
# Processing residue: TIP (ID: 1576) in chain W
# Processing residue: TIP (ID: 1577) in chain W
# Processing residue: TIP (ID: 1578) in chain W
# Processing residue: TIP (ID: 1579) in chain W
# Processing residue: TIP (ID: 1580) in chain W
# Processing residue: TIP (ID: 1581) in chain W
# Processing residue: TIP (ID: 1586) in chain W
# Processing residue: TIP (ID: 1589) in chain W
# Processing residue: TIP (ID: 1590) in chain W
# Processing residue: TIP (ID: 1592) in chain W
# Processing residue: TIP (ID: 1593) in chain W
# Processing residue: TIP (ID: 1598) in chain W
# Processing residue: TIP (ID: 1599) in chain W
# Processing residue: TIP (ID: 1600) in chain W
# Processing residue: TIP (ID: 1602) in chain W
# Processing residue: TIP (ID: 1604) in chain W
# Processing residue: TIP (ID: 1605) in chain W
# Processing residue: TIP (ID: 1609) in chain W
# Processing residue: TIP (ID: 1610) in chain W
# Processing residue: TIP (ID: 1612) in chain W
# Processing residue: TIP (ID: 1616) in chain W
# Processing residue: TIP (ID: 1617) in chain W
# Processing residue: TIP (ID: 1618) in chain W
# Processing residue: TIP (ID: 1620) in chain W
# Processing residue: TIP (ID: 1622) in chain W
# Processing residue: TIP (ID: 1623) in chain W
# Processing residue: TIP (ID: 1624) in chain W
# Processing residue: TIP (ID: 1625) in chain W
# Processing residue: TIP (ID: 1626) in chain W
# Processing residue: TIP (ID: 1628) in chain W
# Processing residue: TIP (ID: 1629) in chain W
# Processing residue: TIP (ID: 1632) in chain W
# Processing residue: TIP (ID: 1638) in chain W
# Processing residue: TIP (ID: 1639) in chain W
# Processing residue: TIP (ID: 1641) in chain W
# Processing residue: TIP (ID: 1642) in chain W
# Processing residue: TIP (ID: 1643) in chain W
# Processing residue: TIP (ID: 1645) in chain W
# Processing residue: TIP (ID: 1646) in chain W
# Processing residue: TIP (ID: 1647) in chain W
# Processing residue: TIP (ID: 1651) in chain W
# Processing residue: TIP (ID: 1656) in chain W
# Processing residue: TIP (ID: 1658) in chain W
# Processing residue: TIP (ID: 1664) in chain W
# Processing residue: TIP (ID: 1667) in chain W
# Processing residue: TIP (ID: 1668) in chain W
# Processing residue: TIP (ID: 1670) in chain W
# Processing residue: TIP (ID: 1671) in chain W
# Processing residue: TIP (ID: 1681) in chain W
# Processing residue: TIP (ID: 1683) in chain W
# Processing residue: TIP (ID: 1686) in chain W
# Processing residue: TIP (ID: 1691) in chain W
# Processing residue: TIP (ID: 1692) in chain W
# Processing residue: TIP (ID: 1693) in chain W
# Processing residue: TIP (ID: 1695) in chain W
# Processing residue: TIP (ID: 1701) in chain W
# Processing residue: TIP (ID: 1704) in chain W
# Processing residue: TIP (ID: 1706) in chain W
# Processing residue: TIP (ID: 1707) in chain W
# Processing residue: TIP (ID: 1708) in chain W
# Processing residue: TIP (ID: 1718) in chain W
# Processing residue: TIP (ID: 1719) in chain W
# Processing residue: TIP (ID: 1722) in chain W
# Processing residue: TIP (ID: 1725) in chain W
# Processing residue: TIP (ID: 1729) in chain W
# Processing residue: TIP (ID: 1730) in chain W
# Processing residue: TIP (ID: 1733) in chain W
# Processing residue: TIP (ID: 1735) in chain W
# Processing residue: TIP (ID: 1737) in chain W
# Processing residue: TIP (ID: 1744) in chain W
# Processing residue: TIP (ID: 1749) in chain W
# Processing residue: TIP (ID: 1750) in chain W
# Processing residue: TIP (ID: 1751) in chain W
# Processing residue: TIP (ID: 1752) in chain W
# Processing residue: TIP (ID: 1755) in chain W
# Processing residue: TIP (ID: 1757) in chain W
# Processing residue: TIP (ID: 1764) in chain W
# Processing residue: TIP (ID: 1766) in chain W
# Processing residue: TIP (ID: 1771) in chain W
# Processing residue: TIP (ID: 1772) in chain W
# Processing residue: TIP (ID: 1773) in chain W
# Processing residue: TIP (ID: 1775) in chain W
# Processing residue: TIP (ID: 1776) in chain W
# Processing residue: TIP (ID: 1778) in chain W
# Processing residue: TIP (ID: 1785) in chain W
# Processing residue: TIP (ID: 1789) in chain W
# Processing residue: TIP (ID: 1794) in chain W
# Processing residue: TIP (ID: 1795) in chain W
# Processing residue: TIP (ID: 1796) in chain W
# Processing residue: TIP (ID: 1808) in chain W
# Processing residue: TIP (ID: 1810) in chain W
# Processing residue: TIP (ID: 1811) in chain W
# Processing residue: TIP (ID: 1812) in chain W
# Processing residue: TIP (ID: 1817) in chain W
# Processing residue: TIP (ID: 1818) in chain W
# Processing residue: TIP (ID: 1820) in chain W
# Processing residue: TIP (ID: 1821) in chain W
# Processing residue: TIP (ID: 1824) in chain W
# Processing residue: TIP (ID: 1829) in chain W
# Processing residue: TIP (ID: 1830) in chain W
# Processing residue: TIP (ID: 1831) in chain W
# Processing residue: TIP (ID: 1833) in chain W
# Processing residue: TIP (ID: 1837) in chain W
# Processing residue: TIP (ID: 1839) in chain W
# Processing residue: TIP (ID: 1841) in chain W
# Processing residue: TIP (ID: 1844) in chain W
# Processing residue: TIP (ID: 1847) in chain W
# Processing residue: TIP (ID: 1851) in chain W
# Processing residue: TIP (ID: 1853) in chain W
# Processing residue: TIP (ID: 1854) in chain W
# Processing residue: TIP (ID: 1856) in chain W
# Processing residue: TIP (ID: 1858) in chain W
# Processing residue: TIP (ID: 1859) in chain W
# Processing residue: TIP (ID: 1862) in chain W
# Processing residue: TIP (ID: 1864) in chain W
# Processing residue: TIP (ID: 1870) in chain W
# Processing residue: TIP (ID: 1871) in chain W
# Processing residue: TIP (ID: 1872) in chain W
# Processing residue: TIP (ID: 1873) in chain W
# Processing residue: TIP (ID: 1875) in chain W
# Processing residue: TIP (ID: 1879) in chain W
# Processing residue: TIP (ID: 1880) in chain W
# Processing residue: TIP (ID: 1883) in chain W
# Processing residue: TIP (ID: 1885) in chain W
# Processing residue: TIP (ID: 1891) in chain W
# Processing residue: TIP (ID: 1892) in chain W
# Processing residue: TIP (ID: 1895) in chain W
# Processing residue: TIP (ID: 1896) in chain W
# Processing residue: TIP (ID: 1897) in chain W
# Processing residue: TIP (ID: 1898) in chain W
# Processing residue: TIP (ID: 1902) in chain W
# Processing residue: TIP (ID: 1906) in chain W
# Processing residue: TIP (ID: 1907) in chain W
# Processing residue: TIP (ID: 1911) in chain W
# Processing residue: TIP (ID: 1913) in chain W
# Processing residue: TIP (ID: 1915) in chain W
# Processing residue: TIP (ID: 1916) in chain W
# Processing residue: TIP (ID: 1918) in chain W
# Processing residue: TIP (ID: 1921) in chain W
# Processing residue: TIP (ID: 1923) in chain W
# Processing residue: TIP (ID: 1925) in chain W
# Processing residue: TIP (ID: 1926) in chain W
# Processing residue: TIP (ID: 1939) in chain W
# Processing residue: TIP (ID: 1942) in chain W
# Processing residue: TIP (ID: 1944) in chain W
# Processing residue: TIP (ID: 1946) in chain W
# Processing residue: TIP (ID: 1947) in chain W
# Processing residue: TIP (ID: 1948) in chain W
# Processing residue: TIP (ID: 1949) in chain W
# Processing residue: TIP (ID: 1950) in chain W
# Processing residue: TIP (ID: 1952) in chain W
# Processing residue: TIP (ID: 1954) in chain W
# Processing residue: TIP (ID: 1955) in chain W
# Processing residue: TIP (ID: 1960) in chain W
# Processing residue: TIP (ID: 1965) in chain W
# Processing residue: TIP (ID: 1976) in chain W
# Processing residue: TIP (ID: 1977) in chain W
# Processing residue: TIP (ID: 1978) in chain W
# Processing residue: TIP (ID: 1984) in chain W
# Processing residue: TIP (ID: 1986) in chain W
# Processing residue: TIP (ID: 1988) in chain W
# Processing residue: TIP (ID: 1989) in chain W
# Processing residue: TIP (ID: 1993) in chain W
# Processing residue: TIP (ID: 1999) in chain W
# Processing residue: TIP (ID: 2000) in chain W
# Processing residue: TIP (ID: 2001) in chain W
# Processing residue: TIP (ID: 2007) in chain W
# Processing residue: TIP (ID: 2009) in chain W
# Processing residue: TIP (ID: 2014) in chain W
# Processing residue: TIP (ID: 2016) in chain W
# Processing residue: TIP (ID: 2022) in chain W
# Processing residue: TIP (ID: 2024) in chain W
# Processing residue: TIP (ID: 2025) in chain W
# Processing residue: TIP (ID: 2027) in chain W
# Processing residue: TIP (ID: 2028) in chain W
# Processing residue: TIP (ID: 2029) in chain W
# Processing residue: TIP (ID: 2031) in chain W
# Processing residue: TIP (ID: 2032) in chain W
# Processing residue: TIP (ID: 2039) in chain W
# Processing residue: TIP (ID: 2041) in chain W
# Processing residue: TIP (ID: 2046) in chain W
# Processing residue: TIP (ID: 2047) in chain W
# Processing residue: TIP (ID: 2048) in chain W
# Processing residue: TIP (ID: 2049) in chain W
# Processing residue: TIP (ID: 2050) in chain W
# Processing residue: TIP (ID: 2052) in chain W
# Processing residue: TIP (ID: 2060) in chain W
# Processing residue: TIP (ID: 2063) in chain W
# Processing residue: TIP (ID: 2065) in chain W
# Processing residue: TIP (ID: 2067) in chain W
# Processing residue: TIP (ID: 2068) in chain W
# Processing residue: TIP (ID: 2069) in chain W
# Processing residue: TIP (ID: 2070) in chain W
# Processing residue: TIP (ID: 2072) in chain W
# Processing residue: TIP (ID: 2073) in chain W
# Processing residue: TIP (ID: 2081) in chain W
# Processing residue: TIP (ID: 2082) in chain W
# Processing residue: TIP (ID: 2083) in chain W
# Processing residue: TIP (ID: 2084) in chain W
# Processing residue: TIP (ID: 2088) in chain W
# Processing residue: TIP (ID: 2089) in chain W
# Processing residue: TIP (ID: 2090) in chain W
# Processing residue: TIP (ID: 2091) in chain W
# Processing residue: TIP (ID: 2092) in chain W
# Processing residue: TIP (ID: 2095) in chain W
# Processing residue: TIP (ID: 2102) in chain W
# Processing residue: TIP (ID: 2103) in chain W
# Processing residue: TIP (ID: 2104) in chain W
# Processing residue: TIP (ID: 2107) in chain W
# Processing residue: TIP (ID: 2109) in chain W
# Processing residue: TIP (ID: 2116) in chain W
# Processing residue: TIP (ID: 2123) in chain W
# Processing residue: TIP (ID: 2124) in chain W
# Processing residue: TIP (ID: 2127) in chain W
# Processing residue: TIP (ID: 2128) in chain W
# Processing residue: TIP (ID: 2129) in chain W
# Processing residue: TIP (ID: 2132) in chain W
# Processing residue: TIP (ID: 2133) in chain W
# Processing residue: TIP (ID: 2135) in chain W
# Processing residue: TIP (ID: 2136) in chain W
# Processing residue: TIP (ID: 2138) in chain W
# Processing residue: TIP (ID: 2143) in chain W
# Processing residue: TIP (ID: 2147) in chain W
# Processing residue: TIP (ID: 2148) in chain W
# Processing residue: TIP (ID: 2150) in chain W
# Processing residue: TIP (ID: 2151) in chain W
# Processing residue: TIP (ID: 2155) in chain W
# Processing residue: TIP (ID: 2156) in chain W
# Processing residue: TIP (ID: 2163) in chain W
# Processing residue: TIP (ID: 2165) in chain W
# Processing residue: TIP (ID: 2167) in chain W
# Processing residue: TIP (ID: 2168) in chain W
# Processing residue: TIP (ID: 2171) in chain W
# Processing residue: TIP (ID: 2172) in chain W
# Processing residue: TIP (ID: 2176) in chain W
# Processing residue: TIP (ID: 2185) in chain W
# Processing residue: TIP (ID: 2186) in chain W
# Processing residue: TIP (ID: 2187) in chain W
# Processing residue: TIP (ID: 2188) in chain W
# Processing residue: TIP (ID: 2194) in chain W
# Processing residue: TIP (ID: 2195) in chain W
# Processing residue: TIP (ID: 2197) in chain W
# Processing residue: TIP (ID: 2198) in chain W
# Processing residue: TIP (ID: 2204) in chain W
# Processing residue: TIP (ID: 2208) in chain W
# Processing residue: TIP (ID: 2211) in chain W
# Processing residue: TIP (ID: 2213) in chain W
# Processing residue: TIP (ID: 2217) in chain W
# Processing residue: TIP (ID: 2219) in chain W
# Processing residue: TIP (ID: 2220) in chain W
# Processing residue: TIP (ID: 2227) in chain W
# Processing residue: TIP (ID: 2228) in chain W
# Processing residue: TIP (ID: 2229) in chain W
# Processing residue: TIP (ID: 2231) in chain W
# Processing residue: TIP (ID: 2233) in chain W
# Processing residue: TIP (ID: 2234) in chain W
# Processing residue: TIP (ID: 2235) in chain W
# Processing residue: TIP (ID: 2236) in chain W
# Processing residue: TIP (ID: 2237) in chain W
# Processing residue: TIP (ID: 2239) in chain W
# Processing residue: TIP (ID: 2240) in chain W
# Processing residue: TIP (ID: 2244) in chain W
# Processing residue: TIP (ID: 2250) in chain W
# Processing residue: TIP (ID: 2254) in chain W
# Processing residue: TIP (ID: 2256) in chain W
# Processing residue: TIP (ID: 2257) in chain W
# Processing residue: TIP (ID: 2258) in chain W
# Processing residue: TIP (ID: 2260) in chain W
# Processing residue: TIP (ID: 2261) in chain W
# Processing residue: TIP (ID: 2270) in chain W
# Processing residue: TIP (ID: 2271) in chain W
# Processing residue: TIP (ID: 2272) in chain W
# Processing residue: TIP (ID: 2275) in chain W
# Processing residue: TIP (ID: 2278) in chain W
# Processing residue: TIP (ID: 2280) in chain W
# Processing residue: TIP (ID: 2281) in chain W
# Processing residue: TIP (ID: 2282) in chain W
# Processing residue: TIP (ID: 2283) in chain W
# Processing residue: TIP (ID: 2285) in chain W
# Processing residue: TIP (ID: 2286) in chain W
# Processing residue: TIP (ID: 2288) in chain W
# Processing residue: TIP (ID: 2290) in chain W
# Processing residue: TIP (ID: 2292) in chain W
# Processing residue: TIP (ID: 2293) in chain W
# Processing residue: TIP (ID: 2295) in chain W
# Processing residue: TIP (ID: 2296) in chain W
# Processing residue: TIP (ID: 2298) in chain W
# Processing residue: TIP (ID: 2301) in chain W
# Processing residue: TIP (ID: 2309) in chain W
# Processing residue: TIP (ID: 2311) in chain W
# Processing residue: TIP (ID: 2313) in chain W
# Processing residue: TIP (ID: 2316) in chain W
# Processing residue: TIP (ID: 2318) in chain W
# Processing residue: TIP (ID: 2321) in chain W
# Processing residue: TIP (ID: 2324) in chain W
# Processing residue: TIP (ID: 2325) in chain W
# Processing residue: TIP (ID: 2326) in chain W
# Processing residue: TIP (ID: 2327) in chain W
# Processing residue: TIP (ID: 2329) in chain W
# Processing residue: TIP (ID: 2331) in chain W
# Processing residue: TIP (ID: 2332) in chain W
# Processing residue: TIP (ID: 2333) in chain W
# Processing residue: TIP (ID: 2336) in chain W
# Processing residue: TIP (ID: 2341) in chain W
# Processing residue: TIP (ID: 2346) in chain W
# Processing residue: TIP (ID: 2351) in chain W
# Processing residue: TIP (ID: 2352) in chain W
# Processing residue: TIP (ID: 2354) in chain W
# Processing residue: TIP (ID: 2355) in chain W
# Processing residue: TIP (ID: 2357) in chain W
# Processing residue: TIP (ID: 2358) in chain W
# Processing residue: TIP (ID: 2359) in chain W
# Processing residue: TIP (ID: 2362) in chain W
# Processing residue: TIP (ID: 2363) in chain W
# Processing residue: TIP (ID: 2364) in chain W
# Processing residue: TIP (ID: 2365) in chain W
# Processing residue: TIP (ID: 2368) in chain W
# Processing residue: TIP (ID: 2376) in chain W
# Processing residue: TIP (ID: 2377) in chain W
# Processing residue: TIP (ID: 2380) in chain W
# Processing residue: TIP (ID: 2384) in chain W
# Processing residue: TIP (ID: 2395) in chain W
# Processing residue: TIP (ID: 2397) in chain W
# Processing residue: TIP (ID: 2404) in chain W
# Processing residue: TIP (ID: 2405) in chain W
# Processing residue: TIP (ID: 2407) in chain W
# Processing residue: TIP (ID: 2417) in chain W
# Processing residue: TIP (ID: 2419) in chain W
# Processing residue: TIP (ID: 2421) in chain W
# Processing residue: TIP (ID: 2424) in chain W
# Processing residue: TIP (ID: 2425) in chain W
# Processing residue: TIP (ID: 2427) in chain W
# Processing residue: TIP (ID: 2428) in chain W
# Processing residue: TIP (ID: 2430) in chain W
# Processing residue: TIP (ID: 2431) in chain W
# Processing residue: TIP (ID: 2436) in chain W
# Processing residue: TIP (ID: 2440) in chain W
# Processing residue: TIP (ID: 2441) in chain W
# Processing residue: TIP (ID: 2443) in chain W
# Processing residue: TIP (ID: 2447) in chain W
# Processing residue: TIP (ID: 2450) in chain W
# Processing residue: TIP (ID: 2458) in chain W
# Processing residue: TIP (ID: 2459) in chain W
# Processing residue: TIP (ID: 2460) in chain W
# Processing residue: TIP (ID: 2462) in chain W
# Processing residue: TIP (ID: 2463) in chain W
# Processing residue: TIP (ID: 2466) in chain W
# Processing residue: TIP (ID: 2471) in chain W
# Processing residue: TIP (ID: 2473) in chain W
# Processing residue: TIP (ID: 2482) in chain W
# Processing residue: TIP (ID: 2483) in chain W
# Processing residue: TIP (ID: 2484) in chain W
# Processing residue: TIP (ID: 2485) in chain W
# Processing residue: TIP (ID: 2486) in chain W
# Processing residue: TIP (ID: 2487) in chain W
# Processing residue: TIP (ID: 2488) in chain W
# Processing residue: TIP (ID: 2489) in chain W
# Processing residue: TIP (ID: 2491) in chain W
# Processing residue: TIP (ID: 2492) in chain W
# Processing residue: TIP (ID: 2494) in chain W
# Processing residue: TIP (ID: 2499) in chain W
# Processing residue: TIP (ID: 2500) in chain W
# Processing residue: TIP (ID: 2503) in chain W
# Processing residue: TIP (ID: 2504) in chain W
# Processing residue: TIP (ID: 2511) in chain W
# Processing residue: TIP (ID: 2512) in chain W
# Processing residue: TIP (ID: 2515) in chain W
# Processing residue: TIP (ID: 2519) in chain W
# Processing residue: TIP (ID: 2521) in chain W
# Processing residue: TIP (ID: 2525) in chain W
# Processing residue: TIP (ID: 2526) in chain W
# Processing residue: TIP (ID: 2527) in chain W
# Processing residue: TIP (ID: 2529) in chain W
# Processing residue: TIP (ID: 2531) in chain W
# Processing residue: TIP (ID: 2533) in chain W
# Processing residue: TIP (ID: 2539) in chain W
# Processing residue: TIP (ID: 2540) in chain W
# Processing residue: TIP (ID: 2544) in chain W
# Processing residue: TIP (ID: 2547) in chain W
# Processing residue: TIP (ID: 2548) in chain W
# Processing residue: TIP (ID: 2550) in chain W
# Processing residue: TIP (ID: 2551) in chain W
# Processing residue: TIP (ID: 2552) in chain W
# Processing residue: TIP (ID: 2553) in chain W
# Processing residue: TIP (ID: 2562) in chain W
# Processing residue: TIP (ID: 2563) in chain W
# Processing residue: TIP (ID: 2564) in chain W
# Processing residue: TIP (ID: 2565) in chain W
# Processing residue: TIP (ID: 2573) in chain W
# Processing residue: TIP (ID: 2574) in chain W
# Processing residue: TIP (ID: 2575) in chain W
# Processing residue: TIP (ID: 2580) in chain W
# Processing residue: TIP (ID: 2582) in chain W
# Processing residue: TIP (ID: 2584) in chain W
# Processing residue: TIP (ID: 2587) in chain W
# Processing residue: TIP (ID: 2588) in chain W
# Processing residue: TIP (ID: 2589) in chain W
# Processing residue: TIP (ID: 2591) in chain W
# Processing residue: TIP (ID: 2592) in chain W
# Processing residue: TIP (ID: 2595) in chain W
# Processing residue: TIP (ID: 2598) in chain W
# Processing residue: TIP (ID: 2606) in chain W
# Processing residue: TIP (ID: 2607) in chain W
# Processing residue: TIP (ID: 2608) in chain W
# Processing residue: TIP (ID: 2610) in chain W
# Processing residue: TIP (ID: 2612) in chain W
# Processing residue: TIP (ID: 2613) in chain W
# Processing residue: TIP (ID: 2617) in chain W
# Processing residue: TIP (ID: 2628) in chain W
# Processing residue: TIP (ID: 2631) in chain W
# Processing residue: TIP (ID: 2635) in chain W
# Processing residue: TIP (ID: 2644) in chain W
# Processing residue: TIP (ID: 2649) in chain W
# Processing residue: TIP (ID: 2650) in chain W
# Processing residue: TIP (ID: 2654) in chain W
# Processing residue: TIP (ID: 2656) in chain W
# Processing residue: TIP (ID: 2657) in chain W
# Processing residue: TIP (ID: 2658) in chain W
# Processing residue: TIP (ID: 2659) in chain W
# Processing residue: TIP (ID: 2662) in chain W
# Processing residue: TIP (ID: 2667) in chain W
# Processing residue: TIP (ID: 2670) in chain W
# Processing residue: TIP (ID: 2672) in chain W
# Processing residue: TIP (ID: 2674) in chain W
# Processing residue: TIP (ID: 2675) in chain W
# Processing residue: TIP (ID: 2676) in chain W
# Processing residue: TIP (ID: 2678) in chain W
# Processing residue: TIP (ID: 2679) in chain W
# Processing residue: TIP (ID: 2680) in chain W
# Processing residue: TIP (ID: 2681) in chain W
# Processing residue: TIP (ID: 2682) in chain W
# Processing residue: TIP (ID: 2683) in chain W
# Processing residue: TIP (ID: 2684) in chain W
# Processing residue: TIP (ID: 2689) in chain W
# Processing residue: TIP (ID: 2690) in chain W
# Processing residue: TIP (ID: 2691) in chain W
# Processing residue: TIP (ID: 2692) in chain W
# Processing residue: TIP (ID: 2693) in chain W
# Processing residue: TIP (ID: 2695) in chain W
# Processing residue: TIP (ID: 2696) in chain W
# Processing residue: TIP (ID: 2698) in chain W
# Processing residue: TIP (ID: 2703) in chain W
# Processing residue: TIP (ID: 2709) in chain W
# Processing residue: TIP (ID: 2710) in chain W
# Processing residue: TIP (ID: 2715) in chain W
# Processing residue: TIP (ID: 2717) in chain W
# Processing residue: TIP (ID: 2718) in chain W
# Processing residue: TIP (ID: 2719) in chain W
# Processing residue: TIP (ID: 2720) in chain W
# Processing residue: TIP (ID: 2721) in chain W
# Processing residue: TIP (ID: 2722) in chain W
# Processing residue: TIP (ID: 2724) in chain W
# Processing residue: TIP (ID: 2734) in chain W
# Processing residue: TIP (ID: 2736) in chain W
# Processing residue: TIP (ID: 2746) in chain W
# Processing residue: TIP (ID: 2753) in chain W
# Processing residue: TIP (ID: 2754) in chain W
# Processing residue: TIP (ID: 2756) in chain W
# Processing residue: TIP (ID: 2761) in chain W
# Processing residue: TIP (ID: 2762) in chain W
# Processing residue: TIP (ID: 2767) in chain W
# Processing residue: TIP (ID: 2771) in chain W
# Processing residue: TIP (ID: 2775) in chain W
# Processing residue: TIP (ID: 2777) in chain W
# Processing residue: TIP (ID: 2779) in chain W
# Processing residue: TIP (ID: 2780) in chain W
# Processing residue: TIP (ID: 2781) in chain W
# Processing residue: TIP (ID: 2783) in chain W
# Processing residue: TIP (ID: 2790) in chain W
# Processing residue: TIP (ID: 2794) in chain W
# Processing residue: TIP (ID: 2795) in chain W
# ...
# Processing residue: TIP (ID: 7125) in chain W
# Processing residue: TIP (ID: 7126) in chain W
# Processing residue: TIP (ID: 7130) in chain W
# Processing residue: TIP (ID: 7132) in chain W
# Processing residue: TIP (ID: 7133) in chain W
# Processing residue: TIP (ID: 7145) in chain W
# Processing residue: TIP (ID: 7147) in chain W
# Processing residue: TIP (ID: 7166) in chain W
# Processing residue: TIP (ID: 7168) in chain W
# Processing residue: TIP (ID: 7170) in chain W
# Processing residue: TIP (ID: 7171) in chain W
# Processing residue: TIP (ID: 7174) in chain W
# Processing residue: TIP (ID: 7176) in chain W
# Processing residue: TIP (ID: 7182) in chain W
# Processing residue: TIP (ID: 7185) in chain W
# Processing residue: TIP (ID: 7193) in chain W
# Processing residue: TIP (ID: 7196) in chain W
# Processing residue: TIP (ID: 7198) in chain W
# Processing residue: TIP (ID: 7203) in chain W
# Processing residue: TIP (ID: 7210) in chain W
# Processing residue: TIP (ID: 7215) in chain W
# Processing residue: TIP (ID: 7216) in chain W
# Processing residue: TIP (ID: 7222) in chain W
# Processing residue: TIP (ID: 7231) in chain W
# Processing residue: TIP (ID: 7252) in chain W
# Processing residue: TIP (ID: 7253) in chain W
# Processing residue: TIP (ID: 7257) in chain W
# Processing residue: TIP (ID: 7271) in chain W
# Processing residue: TIP (ID: 7274) in chain W
# Processing residue: TIP (ID: 7295) in chain W
# Processing residue: TIP (ID: 7305) in chain W
# Processing residue: TIP (ID: 7312) in chain W
# Processing residue: TIP (ID: 7316) in chain W
# Processing residue: TIP (ID: 7321) in chain W
# Processing residue: TIP (ID: 7331) in chain W
# Processing residue: TIP (ID: 7333) in chain W
# Processing residue: TIP (ID: 7351) in chain W
# Processing residue: TIP (ID: 7355) in chain W
# Processing residue: TIP (ID: 7384) in chain W
# Processing residue: TIP (ID: 7396) in chain W
# Processing residue: TIP (ID: 7398) in chain W
# Processing residue: TIP (ID: 7400) in chain W
# Processing residue: TIP (ID: 7405) in chain W
# Processing residue: TIP (ID: 7437) in chain W
# Processing residue: TIP (ID: 7444) in chain W
# Processing residue: TIP (ID: 7479) in chain W
# Processing residue: TIP (ID: 7481) in chain W
# Processing residue: TIP (ID: 7501) in chain W
# Processing residue: TIP (ID: 7525) in chain W
# Processing residue: TIP (ID: 7532) in chain W
# Processing residue: TIP (ID: 7546) in chain W
# Processing residue: TIP (ID: 7567) in chain W
# Processing residue: TIP (ID: 7568) in chain W
# Processing residue: TIP (ID: 7572) in chain W
# Processing residue: TIP (ID: 7592) in chain W
# Processing residue: TIP (ID: 7597) in chain W
# Processing residue: TIP (ID: 7603) in chain W
# Processing residue: TIP (ID: 7605) in chain W
# Processing residue: TIP (ID: 7612) in chain W
# Processing residue: TIP (ID: 7617) in chain W
# Processing residue: TIP (ID: 7630) in chain W
# Processing residue: TIP (ID: 7631) in chain W
# Processing residue: TIP (ID: 7634) in chain W
# Processing residue: TIP (ID: 7635) in chain W
# Processing residue: TIP (ID: 7643) in chain W
# Processing residue: TIP (ID: 7647) in chain W
# Processing residue: TIP (ID: 7650) in chain W
# Processing residue: TIP (ID: 7661) in chain W
# Processing residue: TIP (ID: 7675) in chain W
# Processing residue: TIP (ID: 7676) in chain W
# Processing residue: TIP (ID: 7689) in chain W
# Processing residue: TIP (ID: 7690) in chain W
# Processing residue: TIP (ID: 7692) in chain W
# Processing residue: TIP (ID: 7698) in chain W
# Processing residue: TIP (ID: 7700) in chain W
# Processing residue: TIP (ID: 7702) in chain W
# Processing residue: TIP (ID: 7707) in chain W
# Processing residue: TIP (ID: 7711) in chain W
# Processing residue: TIP (ID: 7712) in chain W
# Processing residue: TIP (ID: 7714) in chain W
# Processing residue: TIP (ID: 7715) in chain W
# Processing residue: TIP (ID: 7716) in chain W
# Processing residue: TIP (ID: 7736) in chain W
# Processing residue: TIP (ID: 7739) in chain W
# Processing residue: TIP (ID: 7748) in chain W
# Processing residue: TIP (ID: 7750) in chain W
# Processing residue: TIP (ID: 7753) in chain W
# Processing residue: TIP (ID: 7754) in chain W
# Processing residue: TIP (ID: 7755) in chain W
# Processing residue: TIP (ID: 7756) in chain W
# Processing residue: TIP (ID: 7762) in chain W
# Processing residue: TIP (ID: 7773) in chain W
# Processing residue: TIP (ID: 7798) in chain W
# Processing residue: TIP (ID: 7811) in chain W
# Processing residue: TIP (ID: 7818) in chain W
# Processing residue: TIP (ID: 7825) in chain W
# Processing residue: TIP (ID: 7833) in chain W
# Processing residue: TIP (ID: 7846) in chain W
# Processing residue: TIP (ID: 7859) in chain W
# Processing residue: TIP (ID: 7860) in chain W
# Processing residue: TIP (ID: 7888) in chain W
# Processing residue: TIP (ID: 7904) in chain W
# Processing residue: TIP (ID: 7905) in chain W
# Processing residue: TIP (ID: 7922) in chain W
# Processing residue: TIP (ID: 7945) in chain W
# Processing residue: TIP (ID: 7951) in chain W
# Processing residue: TIP (ID: 7964) in chain W
# Processing residue: TIP (ID: 7985) in chain W
# Processing residue: TIP (ID: 7987) in chain W
# Processing residue: TIP (ID: 7988) in chain W
# Processing residue: TIP (ID: 8014) in chain W
# Processing residue: TIP (ID: 8023) in chain W
# Processing residue: TIP (ID: 8024) in chain W
# Processing residue: TIP (ID: 8030) in chain W
# Processing residue: TIP (ID: 8046) in chain W
# Processing residue: TIP (ID: 8055) in chain W
# Processing residue: TIP (ID: 8064) in chain W
# Processing residue: TIP (ID: 8067) in chain W
# Processing residue: TIP (ID: 8068) in chain W
# Processing residue: TIP (ID: 8070) in chain W
# Processing residue: TIP (ID: 8073) in chain W
# Processing residue: TIP (ID: 8076) in chain W
# Processing residue: TIP (ID: 8087) in chain W
# Processing residue: TIP (ID: 8091) in chain W
# Processing residue: TIP (ID: 8094) in chain W
# Processing residue: TIP (ID: 8097) in chain W
# Processing residue: TIP (ID: 8107) in chain W
# Processing residue: TIP (ID: 8109) in chain W
# Processing residue: TIP (ID: 8113) in chain W
# Processing residue: TIP (ID: 8115) in chain W
# Processing residue: TIP (ID: 8133) in chain W
# Processing residue: TIP (ID: 8136) in chain W
# Processing residue: TIP (ID: 8140) in chain W
# Processing residue: TIP (ID: 8173) in chain W
# Processing residue: TIP (ID: 8174) in chain W
# Processing residue: TIP (ID: 8176) in chain W
# Processing residue: TIP (ID: 8181) in chain W
# Processing residue: TIP (ID: 8185) in chain W
# Processing residue: TIP (ID: 8193) in chain W
# Processing residue: TIP (ID: 8201) in chain W
# Processing residue: TIP (ID: 8206) in chain W
# Processing residue: TIP (ID: 8212) in chain W
# Processing residue: TIP (ID: 8215) in chain W
# Processing residue: TIP (ID: 8218) in chain W
# Processing residue: TIP (ID: 8222) in chain W
# Processing residue: TIP (ID: 8229) in chain W
# Processing residue: TIP (ID: 8241) in chain W
# Processing residue: TIP (ID: 8243) in chain W
# Processing residue: TIP (ID: 8262) in chain W
# Processing residue: TIP (ID: 8263) in chain W
# Processing residue: TIP (ID: 8264) in chain W
# Processing residue: TIP (ID: 8265) in chain W
# Processing residue: TIP (ID: 8266) in chain W
# Processing residue: TIP (ID: 8284) in chain W
# Processing residue: TIP (ID: 8289) in chain W
# Processing residue: TIP (ID: 8309) in chain W
# Processing residue: TIP (ID: 8326) in chain W
# Processing residue: TIP (ID: 8333) in chain W
# Processing residue: TIP (ID: 8342) in chain W
# Processing residue: TIP (ID: 8345) in chain W
# Processing residue: TIP (ID: 8352) in chain W
# Processing residue: TIP (ID: 8366) in chain W
# Processing residue: TIP (ID: 8368) in chain W
# Processing residue: TIP (ID: 8387) in chain W
# Processing residue: TIP (ID: 8394) in chain W
# Processing residue: TIP (ID: 8403) in chain W
# Processing residue: TIP (ID: 8408) in chain W
# Processing residue: TIP (ID: 8409) in chain W
# Processing residue: TIP (ID: 8411) in chain W
# Processing residue: TIP (ID: 8412) in chain W
# Processing residue: TIP (ID: 8425) in chain W
# Processing residue: TIP (ID: 8436) in chain W
# Processing residue: TIP (ID: 8448) in chain W
# Processing residue: TIP (ID: 8462) in chain W
# Processing residue: TIP (ID: 8466) in chain W
# Processing residue: TIP (ID: 8468) in chain W
# Processing residue: TIP (ID: 8492) in chain W
# Processing residue: TIP (ID: 8509) in chain W
# Processing residue: TIP (ID: 8520) in chain W
# Processing residue: TIP (ID: 8528) in chain W
# Processing residue: TIP (ID: 8534) in chain W
# Processing residue: TIP (ID: 8536) in chain W
# Processing residue: TIP (ID: 8538) in chain W
# Processing residue: TIP (ID: 8548) in chain W
# Processing residue: TIP (ID: 8549) in chain W
# Processing residue: TIP (ID: 8551) in chain W
# Processing residue: TIP (ID: 8556) in chain W
# Processing residue: TIP (ID: 8558) in chain W
# Processing residue: TIP (ID: 8566) in chain W
# Processing residue: TIP (ID: 8574) in chain W
# Processing residue: TIP (ID: 8575) in chain W
# Processing residue: TIP (ID: 8577) in chain W
# Processing residue: TIP (ID: 8578) in chain W
# Processing residue: TIP (ID: 8579) in chain W
# Processing residue: TIP (ID: 8589) in chain W
# Processing residue: TIP (ID: 8599) in chain W
# Processing residue: TIP (ID: 8600) in chain W
# Processing residue: TIP (ID: 8613) in chain W
# Processing residue: TIP (ID: 8621) in chain W
# Processing residue: TIP (ID: 8622) in chain W
# Processing residue: TIP (ID: 8624) in chain W
# Processing residue: TIP (ID: 8642) in chain W
# Processing residue: TIP (ID: 8645) in chain W
# Processing residue: TIP (ID: 8653) in chain W
# Processing residue: TIP (ID: 8658) in chain W
# Processing residue: TIP (ID: 8662) in chain W
# Processing residue: TIP (ID: 8668) in chain W
# Processing residue: TIP (ID: 8675) in chain W
# Processing residue: TIP (ID: 8677) in chain W
# Processing residue: TIP (ID: 8679) in chain W
# Processing residue: TIP (ID: 8680) in chain W
# Processing residue: TIP (ID: 8683) in chain W
# Processing residue: TIP (ID: 8687) in chain W
# Processing residue: TIP (ID: 8689) in chain W
# Processing residue: TIP (ID: 8690) in chain W
# Processing residue: TIP (ID: 8691) in chain W
# Processing residue: TIP (ID: 8695) in chain W
# Processing residue: TIP (ID: 8699) in chain W
# Processing residue: TIP (ID: 8702) in chain W
# Processing residue: TIP (ID: 8705) in chain W
# Processing residue: TIP (ID: 8721) in chain W
# Processing residue: TIP (ID: 8722) in chain W
# Processing residue: TIP (ID: 8726) in chain W
# Processing residue: TIP (ID: 8732) in chain W
# Processing residue: TIP (ID: 8746) in chain W
# Processing residue: TIP (ID: 8748) in chain W
# Processing residue: TIP (ID: 8760) in chain W
# Processing residue: TIP (ID: 8761) in chain W
# Processing residue: TIP (ID: 8780) in chain W
# Processing residue: TIP (ID: 8794) in chain W
# Processing residue: TIP (ID: 8796) in chain W
# Processing residue: TIP (ID: 8800) in chain W
# Processing residue: TIP (ID: 8809) in chain W
# Processing residue: TIP (ID: 8813) in chain W
# Processing residue: TIP (ID: 8822) in chain W
# Processing residue: TIP (ID: 8829) in chain W
# Processing residue: TIP (ID: 8833) in chain W
# Processing residue: TIP (ID: 8836) in chain W
# Processing residue: TIP (ID: 8843) in chain W
# Processing residue: TIP (ID: 8845) in chain W
# Processing residue: TIP (ID: 8848) in chain W
# Processing residue: TIP (ID: 8851) in chain W
# Processing residue: TIP (ID: 8852) in chain W
# Processing residue: TIP (ID: 8865) in chain W
# Processing residue: TIP (ID: 8869) in chain W
# Processing residue: TIP (ID: 8870) in chain W
# Processing residue: TIP (ID: 8886) in chain W
# Processing residue: TIP (ID: 8893) in chain W
# Processing residue: TIP (ID: 8894) in chain W
# Processing residue: TIP (ID: 8896) in chain W
# Processing residue: TIP (ID: 8898) in chain W
# Processing residue: TIP (ID: 8903) in chain W
# Processing residue: TIP (ID: 8905) in chain W
# Processing residue: TIP (ID: 8908) in chain W
# Processing residue: TIP (ID: 8918) in chain W
# Processing residue: TIP (ID: 8926) in chain W
# Processing residue: TIP (ID: 8927) in chain W
# Processing residue: TIP (ID: 8928) in chain W
# Processing residue: TIP (ID: 8935) in chain W
# Processing residue: TIP (ID: 8937) in chain W
# Processing residue: TIP (ID: 8939) in chain W
# Processing residue: TIP (ID: 8940) in chain W
# Processing residue: TIP (ID: 8949) in chain W
# Processing residue: TIP (ID: 8952) in chain W
# Processing residue: TIP (ID: 8954) in chain W
# Processing residue: TIP (ID: 8956) in chain W
# Processing residue: TIP (ID: 8960) in chain W
# Processing residue: TIP (ID: 8961) in chain W
# Processing residue: TIP (ID: 8972) in chain W
# Processing residue: TIP (ID: 8973) in chain W
# Processing residue: TIP (ID: 8976) in chain W
# Processing residue: TIP (ID: 8977) in chain W
# Processing residue: TIP (ID: 8978) in chain W
# Processing residue: TIP (ID: 8988) in chain W
# Processing residue: TIP (ID: 9013) in chain W
# Processing residue: TIP (ID: 9017) in chain W
# Processing residue: TIP (ID: 9035) in chain W
# Processing residue: TIP (ID: 9037) in chain W
# Processing residue: TIP (ID: 9039) in chain W
# Processing residue: TIP (ID: 9044) in chain W
# Processing residue: TIP (ID: 9047) in chain W
# Processing residue: TIP (ID: 9054) in chain W
# Processing residue: TIP (ID: 9055) in chain W
# Processing residue: TIP (ID: 9056) in chain W
# Processing residue: TIP (ID: 9058) in chain W
# Processing residue: TIP (ID: 9059) in chain W
# Processing residue: TIP (ID: 9073) in chain W
# Processing residue: TIP (ID: 9079) in chain W
# Processing residue: TIP (ID: 9080) in chain W
# Processing residue: TIP (ID: 9084) in chain W
# Processing residue: TIP (ID: 9085) in chain W
# Processing residue: TIP (ID: 9096) in chain W
# Processing residue: TIP (ID: 9097) in chain W
# Processing residue: TIP (ID: 9102) in chain W
# Processing residue: TIP (ID: 9105) in chain W
# Processing residue: TIP (ID: 9106) in chain W
# Processing residue: TIP (ID: 9116) in chain W
# Processing residue: TIP (ID: 9124) in chain W
# Processing residue: TIP (ID: 9125) in chain W
# Processing residue: TIP (ID: 9128) in chain W
# Processing residue: TIP (ID: 9136) in chain W
# Processing residue: TIP (ID: 9142) in chain W
# Processing residue: TIP (ID: 9144) in chain W
# Processing residue: TIP (ID: 9157) in chain W
# Processing residue: TIP (ID: 9161) in chain W
# Processing residue: TIP (ID: 9162) in chain W
# Processing residue: TIP (ID: 9165) in chain W
# Processing residue: TIP (ID: 9181) in chain W
# Processing residue: TIP (ID: 9183) in chain W
# Processing residue: TIP (ID: 9184) in chain W
# Processing residue: TIP (ID: 9186) in chain W
# Processing residue: TIP (ID: 9188) in chain W
# Processing residue: TIP (ID: 9189) in chain W
# Processing residue: TIP (ID: 9196) in chain W
# Processing residue: TIP (ID: 9198) in chain W
# Processing residue: TIP (ID: 9206) in chain W
# Processing residue: TIP (ID: 9208) in chain W
# Processing residue: TIP (ID: 9211) in chain W
# Processing residue: TIP (ID: 9212) in chain W
# Processing residue: TIP (ID: 9213) in chain W
# Processing residue: TIP (ID: 9223) in chain W
# Processing residue: TIP (ID: 9226) in chain W
# Processing residue: TIP (ID: 9234) in chain W
# Processing residue: TIP (ID: 9250) in chain W
# Processing residue: TIP (ID: 9251) in chain W
# Processing residue: CLA (ID: 1) in chain I
# Processing residue: CLA (ID: 2) in chain I
# Processing residue: CLA (ID: 3) in chain I
# Processing residue: CLA (ID: 4) in chain I
# Total positions found: 124
# Positions string: KU1h,EU2h,TU3h,AU4h,AU5h,AU6h,KU7h,FU8h,EU9h,RU10h,QU11h,HU12h,MU13h,DU14h,SU15h,SU16h,TU17h,SU18h,AU19h,AU20h,SU21h,SU22h,SU23h,NU24h,YU25h,CU26h,NU27h,QU28h,MU29h,MU30h,KU31h,SU32h,RU33h,NU34h,LU35h,TU36h,KU37h,DU38h,RU39h,CU40h,KU41h,PU42h,VU43h,NU44h,TU45h,FU46h,VU47h,HU48h,EU49h,SU50h,LU51h,AU52h,DU53h,VU54h,QU55h,AU56h,VU57h,CU58h,SU59h,QU60h,KU61h,NU62h,VU63h,AU64h,CU65h,KU66h,NU67h,GU68h,QU69h,TU70h,NU71h,CU72h,YU73h,QU74h,SU75h,YU76h,SU77h,TU78h,MU79h,SU80h,IU81h,TU82h,DU83h,CU84h,RU85h,EU86h,TU87h,GU88h,SU89h,SU90h,KU91h,YU92h,PU93h,NU94h,CU95h,AU96h,YU97h,KU98h,TU99h,TU100h,QU101h,AU102h,NU103h,KU104h,HU105h,IU106h,IU107h,VU108h,AU109h,CU110h,EU111h,GU112h,NU113h,PU114h,YU115h,VU116h,PU117h,VU118h,HU119h,FU120h,DU121h,AU122h,SU123h,VU124h
# Updated config.cfg with 124 positions.
